# %% [markdown]
# <a href="https://colab.research.google.com/github/alvarojd/SolarForecasting/blob/main/LSTM/LSTM_Univariable_Array_MinMax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LSTM NN UNIVARIABLE**
#
# ---
#
#
# > Red neuronal Long short term memory, entrenada con solo una variable, irradiacia global horizontal.
#
# ---
#
# **BASE DE DATOS:** KENYA

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# ---
# # 1.   **SE IMPORTAN LAS BIBLIOTECAS NECESARIAS**
#
# ---

# %% [markdown]
#   Importamos las librerias necesarias para todo el script:
#
# 1.   **Matplotlib** para realizar las gráficas
# 2.   **Pandas** para procesar la base de datos
# 3.   **Numpy** para convertir la base de datos en arreglos numéricos
# 4.   **Os** para acceder a los archivos mediante rutas de almacenamiento
# 5.   **Seaborn** para realizar análisis gráficos a los datos mediante análisis estadisticos
# 6.   **Drive** se utiliza para acceder a las carpetas de datos del drive de un correo asociado
# 7.   **Tensorflow** es la librería mediante la cual se generan los modelos de redes neuronales

# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from google.colab import drive 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
mpl.rcParams['figure.figsize'] = (8, 6) #Definimos el tamaño para las figuras de matplotlib
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ---
#
#
# # 2.   **SE CARGA EL DATASET PREVIAMENTE PROCESADO**
#
# ---

# %% [markdown]
# En la siguiente celda de codigo se llama una función de google colab mediante la cual se accede a la carpeta de drive, luego se define la ruta de acceso a la base de datos previamente procesados para la realización del modelo y se procesa mediante la librería `Pandas`:

# %%
ruta='https://raw.githubusercontent.com/alvarojd/SolarForecasting/main/DATASETS/KENYA_LIMPIO.csv'
data = pd.read_csv(ruta,encoding='utf-8') # Se hace la respectiva lectura, no se añade encabezado o indice, por lo que pondrá por defecto la numeracion
data.set_index('time', inplace=True) # Establecemos cual será el indice del dataframe
data.head(2) # Se muestran las 5 primeras filas del dataframe

# %% [markdown]
# ---
#
#
# # 3. **SE SELECCIONAN LOS DATOS A UTILIZAR PARA EL ENTRENAMIENTO DEL MODELO**
#
#
# ---

# %% [markdown]
# Luego de analizar las corelaciones, se llego a la conclusion de que los datos que más influencia tienen sobre los valores de irradianza `GHI` son los que se seleccionaron y se colocaron en un nuevo dataset:

# %%
features_considered = ['ghi_pyr_1']
features = data[features_considered] # Creamos un dataframe con solo estos datos
features.head() #Se muestran los 5 primeros datos
# Out:
#                      ghi_pyr_1
# time
# 2019-12-12 00:00:00        0.0
# 2019-12-12 00:15:00        0.0
# 2019-12-12 00:30:00        0.0
# 2019-12-12 00:45:00        0.0
# 2019-12-12 01:00:00        0.0

# %% [markdown]
# Graficamos todos los datos con el fin de apreciar de manera general su comportamiento a lo largo del tiempo con la función plot asociada a la librería `Pandas`.

# %%
features.plot(subplots=True) # Graficamos las columnas de datos para observar su comportamiento
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe5711edd90>],
#       dtype=object)

# %% [markdown]
# Se convierte el conjunto de datos en un arreglo de `numpy` definiendo la cantidad de datos que se van a utilizar para el proceso y luego se estandarizan con una normalización:

# %%
TRAIN_SPLIT = int(len(features)*0.8//1) #Definimos la cantidad de datos que se van a usar para el entrenamiento del modelo
dataset = features.values # Convertimos el dataframe en un arreglo de numpy

# %% [markdown]
# ---
#
#
# 3_1. **ESCALAMIENTO DE LOS DATOS**
#
#
# ---

# %%
scaler = MinMaxScaler()
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# ---
#
#
# # 4.   **SE DEFINE LA FUNCIÓN QUE SE UTILIZA PARA LA PARTICIÓN DE LOS DATOS EN VENTANAS MOVILES**
#
# ---

# %%
def ventanas(dataset,xsize,ysize,indexin,indexf):
  #dataset = dataset.T
  n=0
  x=[]
  y=[]
  for i in range(int(((indexf-indexin)/xsize)-1)):
    x.append(dataset[n+indexin:n+indexin+xsize].T)
    y.append(dataset[n+indexin+xsize:n+indexin+xsize+ysize].T)
    n+=xsize
  return np.array(x),np.array(y)

# %%
x_train1,y_train1=ventanas(dataset,96,96,0,TRAIN_SPLIT)
x_val1,y_val1=ventanas(dataset,96,96,308*96,len(dataset))

# %%
x_train1.shape
# Out:
# (307, 1, 96)

# %% [markdown]
# ---
#
#
# # 5.   **FUNCIÓN PARA VISUALIZAR LOS RESULTADOS OBTENIDOS**
#
#
# ---

# %% [markdown]
# La siguiente de función se utiliza para generar gráficos a partir de una ventana de tiempo como las que se definieron anteriormente, esta se utilizará para mostrar:
#
# *   La ventana de tiempo utilizada para la predicción
# *   El valor real de los datos futuros tomado del set de validación
# *   El valor de las predicciones que arroja la red neuronal

# %%
def create_time_steps(length): # Función que crea un array en un rango determinado por el tamaño de la ventana de datos
    return list(range(-length, 0))

# history: Un arreglo con la ventana de datos usada para la predicción
# true_future: Arreglo con los datos conocidos que deberia arrojar la predicción 
# prediction: Arreglo con las predicciones obtenidas

def multi_step_plot(history, true_future, prediction): 
    plt.figure(figsize=(12, 6)) # Se define el tamaño de la figura
    num_in = create_time_steps(len(history)) #Tamaño de la curva de datos pasados
    num_out = len(true_future) # Tamaño de la curva de datos futuros
    plt.plot(num_in, history, label='History') # Graficamos datos pasados
    plt.plot(np.arange(num_out)/STEP, (true_future), 'y--',
           label='True Future') #Graficamos datos furutos
    if prediction.any(): # Si se ingresan datos sobre las predicciones
        plt.plot(np.arange(num_out)/STEP, (prediction), 'r--', #Grafica tambien las predicciones
                 label='Predicted Future')
    plt.legend(loc='upper left') # Ajustes de la grafica
    plt.grid()
    plt.show() # Se muestra la grafica

# %% [markdown]
# ---
#  # 6. **CREACIÓN Y ENTRENAMIENTO DEL MODELO**
#
# ---

# %% [markdown]
# En las siguientes celdas de texto se va a definir el modelo de ML que se utilizará para realizar las predicciones buscadas, este modelo consta de una capa de entrada, y dos capas intermedias de neuronas tipo LSTM, con una respectiva función de activación.
#
# ![RedNeuronalArtificial.png](data:image/png;base64,...)
#
# Fig 1. [Perceptrón Multicapa](https://es.wikipedia.org/wiki/Perceptr%C3%B3n_multicapa)
#
# La cantidad de neuronas ajustada de forma manual para maximizar su precisión de entrenamiento y una capa de salida con n neuronas con n datos de predicción buscados.
#
# Además se compila el modelo y dentro de dicha compilación estan incluidas configuraciónes, donde las configuraciones son:
#
# *   **optimizer**: Optimizador utilizado
# *   **loss**: Métrica utilizada para determinar las perdidas del modelo
# *   **metrics**: Guarda los valores de las metricas en cada epoca de entrenamiento

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss')<0.03):
      print("\nReached less than 0.02 losses so cancelling training!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
batch_size=1

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(100, activation="tanh", stateful= True, batch_input_shape= (batch_size, x_train1.shape[1], x_train1.shape[2]),  dropout=0.2, return_sequences=True),
    tf.keras.layers.LSTM(150, activation="tanh", stateful= True, dropout=0.2,return_sequences=True),
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(96))
])

model.compile(optimizer='adam', loss='mean_absolute_error')# Compilamos el modelo y definimos los ajustes ya explicados

# %%
history = model.fit(x_train1, y_train1, epochs=300, verbose=1, validation_data=(x_val1, y_val1), batch_size=batch_size, shuffle=False, callbacks=[callbacks])
# Out:
# Epoch 1/300
# 307/307 [==============================] - 10s 8ms/step - loss: 0.0613 - val_loss: 0.0369
# Epoch 2/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0407 - val_loss: 0.0297
# Epoch 3/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0387 - val_loss: 0.0292
# Epoch 4/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0376 - val_loss: 0.0275
# Epoch 5/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0371 - val_loss: 0.0265
# Epoch 6/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0368 - val_loss: 0.0264
# Epoch 7/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0366 - val_loss: 0.0262
# Epoch 8/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0364 - val_loss: 0.0260
# Epoch 9/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0365 - val_loss: 0.0260
# Epoch 10/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0363 - val_loss: 0.0259
# Epoch 11/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0364 - val_loss: 0.0256
# Epoch 12/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0364 - val_loss: 0.0259
# Epoch 13/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0360 - val_loss: 0.0256
# Epoch 14/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0363 - val_loss: 0.0258
# Epoch 15/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0363 - val_loss: 0.0257
# Epoch 16/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0360 - val_loss: 0.0259
# Epoch 17/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0362 - val_loss: 0.0258
# Epoch 18/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0363 - val_loss: 0.0258
# Epoch 19/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0361 - val_loss: 0.0260
# Epoch 20/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0360 - val_loss: 0.0258
# Epoch 21/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0361 - val_loss: 0.0257
# Epoch 22/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0361 - val_loss: 0.0256
# Epoch 23/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0362 - val_loss: 0.0258
# Epoch 24/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0360 - val_loss: 0.0259
# Epoch 25/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0359 - val_loss: 0.0258
# Epoch 26/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0360 - val_loss: 0.0258
# Epoch 27/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0357 - val_loss: 0.0258
# Epoch 28/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0361 - val_loss: 0.0259
# Epoch 29/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0357 - val_loss: 0.0257
# Epoch 30/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0354 - val_loss: 0.0256
# Epoch 31/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0353 - val_loss: 0.0259
# Epoch 32/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0352 - val_loss: 0.0256
# Epoch 33/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0349 - val_loss: 0.0256
# Epoch 34/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0347 - val_loss: 0.0256
# Epoch 35/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0342 - val_loss: 0.0255
# Epoch 36/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0338 - val_loss: 0.0258
# Epoch 37/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0332 - val_loss: 0.0257
# Epoch 38/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0330 - val_loss: 0.0255
# Epoch 39/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0330 - val_loss: 0.0253
# Epoch 40/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0327 - val_loss: 0.0252
# Epoch 41/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0323 - val_loss: 0.0256
# Epoch 42/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0323 - val_loss: 0.0254
# Epoch 43/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0321 - val_loss: 0.0259
# Epoch 44/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0318 - val_loss: 0.0255
# Epoch 45/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0319 - val_loss: 0.0256
# Epoch 46/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0316 - val_loss: 0.0257
# Epoch 47/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0316 - val_loss: 0.0259
# Epoch 48/300
# 307/307 [==============================] - 2s 6ms/step - loss: 0.0317 - val_loss: 0.0255
# Epoch 49/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0313 - val_loss: 0.0261
# Epoch 50/300
# 307/307 [==============================] - 2s 6ms/step - loss: 0.0313 - val_loss: 0.0256
# Epoch 51/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0314 - val_loss: 0.0254
# Epoch 52/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0313 - val_loss: 0.0253
# Epoch 53/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0309 - val_loss: 0.0253
# Epoch 54/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0313 - val_loss: 0.0253
# Epoch 55/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0311 - val_loss: 0.0256
# Epoch 56/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0311 - val_loss: 0.0255
# Epoch 57/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0310 - val_loss: 0.0251
# Epoch 58/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0312 - val_loss: 0.0255
# Epoch 59/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0308 - val_loss: 0.0256
# Epoch 60/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0306 - val_loss: 0.0251
# Epoch 61/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0305 - val_loss: 0.0255
# Epoch 62/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0312 - val_loss: 0.0251
# Epoch 63/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0308 - val_loss: 0.0252
# Epoch 64/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0310 - val_loss: 0.0252
# Epoch 65/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0308 - val_loss: 0.0257
# Epoch 66/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0305 - val_loss: 0.0256
# Epoch 67/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0304 - val_loss: 0.0252
# Epoch 68/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0307 - val_loss: 0.0255
# Epoch 69/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0308 - val_loss: 0.0252
# Epoch 70/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0306 - val_loss: 0.0254
# Epoch 71/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0306 - val_loss: 0.0254
# Epoch 72/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0306 - val_loss: 0.0252
# Epoch 73/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0305 - val_loss: 0.0250
# Epoch 74/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0255
# Epoch 75/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0251
# Epoch 76/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0306 - val_loss: 0.0251
# Epoch 77/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0304 - val_loss: 0.0251
# Epoch 78/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0307 - val_loss: 0.0256
# Epoch 79/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0302 - val_loss: 0.0252
# Epoch 80/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0307 - val_loss: 0.0252
# Epoch 81/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0254
# Epoch 82/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0257
# Epoch 83/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0302 - val_loss: 0.0253
# Epoch 84/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0256
# Epoch 85/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0300 - val_loss: 0.0253
# Epoch 86/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0301 - val_loss: 0.0252
# Epoch 87/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0305 - val_loss: 0.0250
# Epoch 88/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0305 - val_loss: 0.0254
# Epoch 89/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0301 - val_loss: 0.0254
# Epoch 90/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0303 - val_loss: 0.0252
# Epoch 91/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0301 - val_loss: 0.0252
# Epoch 92/300
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0301 - val_loss: 0.0252
# Epoch 93/300
# 307/307 [==============================] - ETA: 0s - loss: 0.0297
# Reached less than 0.02 losses so cancelling training!
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0297 - val_loss: 0.0253

# %% [markdown]
# ---
#
#
# # 7. **RESULTADOS** 📃
#
#
# ---

# %% [markdown]
# En esta sección del codigo se observarán y analizarán los resultados obtenidos realizando predicciones con el modelo que generamos.  ✌

# %%
def metricas(history):
  loss     = history.history[    'loss' ]
  val_loss = history.history['val_loss' ]


  epochs   = range(1,len(loss)+1,1)
  plt.plot ( epochs,     loss, 'r--', label='Training loss' )
  plt.plot ( epochs, val_loss ,  'b', label='Validation loss' )
  plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
  plt.title ('Training and Validation losses'   )
  plt.ylabel('Loss')
  plt.xlabel('Epochs')
  plt.grid(True)

  plt.legend()
  plt.figure() 

metricas(history)

# %% [markdown]
# **EVALUACIÓN DEL MODELO**

# %%
model.evaluate(x_val1, y_val1),model.evaluate(x_train1, y_train1)
# Out:
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0253
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0329
# (0.02534599043428898, 0.03287973999977112)

# %% [markdown]
# **CÁLCULO DE LAS MÉTRICAS DE ERROR**

# %%
len(x_train1)
# Out:
# 307

# %%
n=0
MAPE = []
MAE = []
RMSE = []
for i in range(len(x_train1)):
  xt= x_train1[n][0]
  yt= y_train1[n][0]
  y=model.predict(np.array([x_train1[n]]))[0][0]
  mape= ((y-yt).mean())*100
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))
  mae = abs((y-yt).mean())
  rmse = abs(y-yt).mean()

  MAPE.append(mape)
  MAE.append(mae)
  RMSE.append(rmse)
  n+=1
tMAPE =np.array(MAPE).mean()
tMAE =np.array(MAE).mean()
tRMSE =np.array(RMSE).mean()

n=0
MAPE = []
MAE = []
RMSE = []
for i in range(len(x_val1)):
  xt= x_val1[n][0]
  yt= y_val1[n][0]
  y=model.predict(np.array([x_val1[n]]))[0][0]
  mape= ((y-yt).mean())*100
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))
  mae = abs((y-yt).mean())
  rmse = abs(y-yt).mean()

  MAPE.append(mape)
  MAE.append(mae)
  RMSE.append(rmse)
  n+=1
  
vMAPE =np.array(MAPE).mean()
vMAE =np.array(MAE).mean()
vRMSE =np.array(RMSE).mean()

# %%
print("----------------------------------")
print("|  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de entrenamiento")
print("----------------------------------")
print("%9.4f%12.4f%12.4f"%(tMAE,tMAPE,tRMSE))
print("----------------------------------")
print("|  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de validación")
print("----------------------------------")
print("%9.4f%12.4f%12.4f"%(vMAE,vMAPE,vRMSE))
print("----------------------------------")
# Out:
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de entrenamiento
# ----------------------------------
#   32.5616      1.8874     50.9785
# ----------------------------------
# |  MAE   |   MAPE[%] |       RMSE  |    <-------- Promedio de errores del set completo de validación
# ----------------------------------
#   20.6994      1.0508     39.2405
# ----------------------------------

# %% [markdown]
# **GRÁFICOS CON LOS DATOS DE ENTRENAMIENTO**

# %%
STEP = 1
n=0
for i in range(5):
  xt= x_train1[n][0]
  yt= y_train1[n][0]
  y=model.predict(np.array([x_train1[n]]))[0][0]
  mae= abs((y-yt).mean())
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))

  multi_step_plot(xt[0], yt[0], y[0])
  print('El MAPE para un horizonte de 24h es:',mae*100,'%')
  n+=1
# Out:
# El MAPE para un horizonte de 24h es: 1.4322207736447277 %
# El MAPE para un horizonte de 24h es: 3.3705577781144136 %
# El MAPE para un horizonte de 24h es: 0.4866872955591693 %
# El MAPE para un horizonte de 24h es: 0.7506226088695979 %
# El MAPE para un horizonte de 24h es: 1.4126523562406257 %

# %% [markdown]
# **GRÁFICOS CON LOS DATOS DE VALIDACIÓN**

# %%
STEP = 1
n=0
for i in range(5):
  xt= x_val1[n][0]
  yt= y_val1[n][0]
  y=model.predict(np.array([x_val1[n]]))[0][0]
  mae= abs((y-yt).mean())
  xt= scaler.inverse_transform(xt.reshape((96,1))).reshape((1,96))
  yt= scaler.inverse_transform(yt.reshape((96,1))).reshape((1,96)) 
  y=scaler.inverse_transform(y.reshape((96,1))).reshape((1,96))

  multi_step_plot(xt[0], yt[0], y[0])
  print('El MAPE para un horizonte de 24h es:',mae*100,'%')
  n+=1
# Out:
# El MAPE para un horizonte de 24h es: 1.0596700010106237 %
# El MAPE para un horizonte de 24h es: 0.21626957074437395 %
# El MAPE para un horizonte de 24h es: 0.5747450396490431 %
# El MAPE para un horizonte de 24h es: 0.5059320870026501 %
# El MAPE para un horizonte de 24h es: 2.8502424912901505 %
